# %%
# Start writing code here...def celcius (a_string):
def celcius (a_string):
    out = a_string.replace("°", "")
    cel = round((int(out) - 32) * 5.0/9.0)
    return cel


def scrape ():
    import requests
    import pandas as pd
    from bs4 import BeautifulSoup

    page = requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
    soup = BeautifulSoup(page.content, 'html.parser')
    rows_list = []

    header = soup.findAll("details", {"summarycontentclassname": "DaypartDetails--DetailSummaryContent--1c28m"})
    for each in header:
        weatherResults = {}
        date = []
        date = each.find("h2", {"class": "DetailsSummary--daypartName--1Mebr"}).get_text(strip=True).split()
        weatherResults["Day of Week"] = date[0]
        if len(date) == 2:
            weatherResults["Day Date"] =  date[1]
        else:
            weatherResults["Day Date"] = ""
            
        weatherResults["Temp High"] = celcius(each.find("span", {"class": "DetailsSummary--highTempValue--3x6cL"}).get_text(strip=True)) # DetailsSummary--highTempValue--3x6cL
        weatherResults["Temp Low"] = celcius(each.find("span", {"class": "DetailsSummary--lowTempValue--1DlJK"}).get_text(strip=True))  # DetailsSummary--lowTempValue--1DlJK
        weatherResults["Summary"] = each.find("p", {"class": "DailyContent--narrative--3AcXd"}).get_text(strip=True)                    # DailyContent--narrative--3AcXd
        rows_list.append(weatherResults)                               
                                  
    df = pd.DataFrame(rows_list)    
    return df
scrape ()
# Out:
#    Day of Week Day Date  Temp High  Temp Low  \
# 0        Today                  18         7
# 1          Thu       10         14         6
# 2          Fri       11         13         8
# 3          Sat       12         14         9
# 4          Sun       13         14         9
# 5          Mon       14         14         7
# 6          Tue       15         14         7
# 7          Wed       16         14         8
# 8          Thu       17         14         7
# 9          Fri       18         14         7
# 10         Sat       19         16         7
# 11         Sun       20         16         7
# 12         Mon       21         16         6
# 13         Tue       22         16         6
# 14         Wed       23         16         6
#
#                                               Summary
# 0   A mix of clouds and sun. High 64F. Winds N at ...
# 1   A few clouds early, otherwise mostly sunny. Hi...
# 2   Partly cloudy. High 56F. Winds WNW at 10 to 15...
# 3   Cloudy with showers. High 57F. Winds SSW at 5 ...
# 4   A steady rain in the morning. Showers continui...
# 5   Sunshine and clouds mixed. High 58F. Winds WNW...
# 6    Partly cloudy. High 57F. Winds W at 5 to 10 mph.
# 7   Mostly cloudy in the morning then periods of s...
# 8   Overcast with rain showers at times. High 58F....
# 9   A few showers early with mostly cloudy conditi...
# 10  Showers in the morning with some clearing in t...
# 11  Mostly cloudy skies early will become partly c...
# 12  Sunshine and clouds mixed. High near 60F. Wind...
# 13  Mostly sunny skies. High near 60F. Winds N at ...
# 14  Mostly sunny skies. High 61F. Winds N at 5 to ...
